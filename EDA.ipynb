# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
# %matplotlib inline
mpl.style.use('ggplot')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
## Display all the columns of the dataframe

pd.pandas.set_option('display.max_columns',None)

# %%
df = pd.read_csv('DS.csv')

# %%
pip install sklearn

# %%
import sklearn

# %%
sklearn.__version__
# Out:
# '1.0.2'

# %%
df
# Out:
#                       Car_Name Manufacturer  Year  Kms_Driven Fuel_Type  \
# 0      Maruti Suzuki Dzire Ldi       Maruti  2011      100000    Diesel
# 1      Maruti Suzuki Dzire Ldi       Maruti  2011      100000    Diesel
# 2      Maruti Suzuki Dzire vdi       Maruti  2011       25000    Diesel
# 3      Maruti Suzuki Dzire Zdi       Maruti  2011       50000    Diesel
# 4      Maruti Suzuki Dzire Ldi       Maruti  2011      100000    Diesel
# ...                        ...          ...   ...         ...       ...
# 1463   Toyota Fortuner 2.8 4X2       Toyota  2021        5698    Diesel
# 1464  Toyota Fortuner 2.8 4X4        Toyota  2021       20452    Diesel
# 1465   Toyota Fortuner 2.8 4X4       Toyota  2021        4800    Diesel
# 1466          Toyota Legender        Toyota  2021        9000    Diesel
# 1467       Toyota Legender 4X4       Toyota  2021       15478    Diesel
#
#      Seller_Type Transmission  No_Of_Owners Present_Price Selling_Price  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1468 entries, 0 to 1467
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       1468 non-null   object
#  1   Manufacturer   1468 non-null   object
#  2   Year           1468 non-null   int64
#  3   Kms_Driven     1468 non-null   int64
#  4   Fuel_Type      1468 non-null   object
#  5   Seller_Type    1468 non-null   object
#  6   Transmission   1468 non-null   object
#  7   No_Of_Owners   1468 non-null   int64
#  8   Present_Price  1468 non-null   object
#  9   Selling_Price  1468 non-null   object
#  10  Insurance      1468 non-null   object
# dtypes: int64(3), object(8)
# memory usage: 126.3+ KB

# %%
df.isnull().sum()
# Out:
# Car_Name         0
# Manufacturer     0
# Year             0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# No_Of_Owners     0
# Present_Price    0
# Selling_Price    0
# Insurance        0
# dtype: int64

# %%
#checking the distribution of categorical data
df['Transmission'].value_counts()
# Out:
# Manual       1218
# Automatic     250
# Name: Transmission, dtype: int64

# %%
df['Manufacturer'].value_counts()
# Out:
# Maruti        448
# Toyota        253
# Hyundai       215
# Honda         171
# Mahindra      159
# Volkswagen     78
# Renault        54
# Nissan         41
# Kia            21
# MG             20
# Jeep            8
# Name: Manufacturer, dtype: int64

# %%
df['Seller_Type'].value_counts()
# Out:
# Individual    1351
# Dealer         117
# Name: Seller_Type, dtype: int64

# %%
df['Fuel_Type'].value_counts()
# Out:
# Diesel      840
# Petrol      616
# CNG           7
# Electric      3
# LPG           2
# Name: Fuel_Type, dtype: int64

# %%
df_num = df.copy()

# %%
df_num
# Out:
#                       Car_Name Manufacturer  Year  Kms_Driven Fuel_Type  \
# 0      Maruti Suzuki Dzire Ldi       Maruti  2011      100000    Diesel
# 1      Maruti Suzuki Dzire Ldi       Maruti  2011      100000    Diesel
# 2      Maruti Suzuki Dzire vdi       Maruti  2011       25000    Diesel
# 3      Maruti Suzuki Dzire Zdi       Maruti  2011       50000    Diesel
# 4      Maruti Suzuki Dzire Ldi       Maruti  2011      100000    Diesel
# ...                        ...          ...   ...         ...       ...
# 1463   Toyota Fortuner 2.8 4X2       Toyota  2021        5698    Diesel
# 1464  Toyota Fortuner 2.8 4X4        Toyota  2021       20452    Diesel
# 1465   Toyota Fortuner 2.8 4X4       Toyota  2021        4800    Diesel
# 1466          Toyota Legender        Toyota  2021        9000    Diesel
# 1467       Toyota Legender 4X4       Toyota  2021       15478    Diesel
#
#      Seller_Type Transmission  No_Of_Owners Present_Price Selling_Price  \
# ...

# %%
df['Selling_Price'] = df['Selling_Price'].str.replace(',','').astype(float)

# %%
df['Selling_Price'] = df['Selling_Price'].astype(int)

# %%
df['Present_Price'] = df['Present_Price'].str.replace(',','').astype(float)

# %%
df['Present_Price'] = df['Present_Price'].astype(int)

# %%
df_num['Selling_Price'] = df_num['Selling_Price'].str.replace(',','').astype(float)

# %%
df_num['Selling_Price'] = df_num['Selling_Price'].astype(int)

# %%
df_num['Present_Price'] = df_num['Present_Price'].str.replace(',','').astype(float)

# %%
df_num['Present_Price'] = df_num['Present_Price'].astype(int)

# %%
df_num.describe()
# Out:
#               Year     Kms_Driven  No_Of_Owners  Present_Price  Selling_Price
# count  1468.000000    1468.000000   1468.000000   1.468000e+03   1.468000e+03
# mean   2016.164850   64456.229564      1.119210   1.210352e+06   7.652053e+05
# std       3.266623   40928.588793      0.352359   7.673049e+05   6.774760e+05
# min    2008.000000    1456.000000      1.000000   6.120000e+04   2.000000e+00
# 25%    2014.000000   36529.000000      1.000000   7.570000e+05   3.750000e+05
# 50%    2017.000000   65482.000000      1.000000   9.900000e+05   5.825000e+05
# 75%    2019.000000   85324.000000      1.000000   1.354000e+06   8.800000e+05
# max    2021.000000  855000.000000      3.000000   5.336000e+06   9.200000e+06

# %%
df['Fuel_Type'].unique()
# Out:
# array(['Diesel', 'Petrol', 'CNG', 'LPG', 'Electric'], dtype=object)

# %%
df['Transmission'].unique()
# Out:
# array(['Manual', 'Automatic'], dtype=object)

# %%
df['Insurance'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
df['Seller_Type'].unique()
# Out:
# array(['Individual', 'Dealer'], dtype=object)

# %%
#encoding Categorical Features
# encoding "Fuel_Type" Column
df_num.replace({'Fuel_Type':{'Diesel':0,'Petrol':1,'CNG':2,'LPG':3,'Electric':4}},inplace=True)

# encoding "Seller_Type" Column
df_num.replace({'Seller_Type':{'Dealer':0,'Individual':1}},inplace=True)

# encoding "Transmission" Column
df_num.replace({'Transmission':{'Manual':0,'Automatic':1}},inplace=True)

#encoding "Insurance" Column
df_num.replace({'Insurance':{'Yes':1,'No':0}},inplace=True)

# %%
df_num.dtypes
# Out:
# Car_Name         object
# Manufacturer     object
# Year              int64
# Kms_Driven        int64
# Fuel_Type         int64
# Seller_Type       int64
# Transmission      int64
# No_Of_Owners      int64
# Present_Price     int32
# Selling_Price     int32
# Insurance         int64
# dtype: object

# %%
df.dtypes
# Out:
# Car_Name         object
# Manufacturer     object
# Year              int64
# Kms_Driven        int64
# Fuel_Type        object
# Seller_Type      object
# Transmission     object
# No_Of_Owners      int64
# Present_Price     int32
# Selling_Price     int32
# Insurance        object
# dtype: object

# %%
from pandas_profiling import ProfileReport

# %%
ProfileReport(df_num)
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated with the `pandas-profiling` Python package&quot;&gt;&lt;meta name=author content=&quot;Simon Brugman and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v3.1.0&quot;&gt;&lt;meta name=url content=https://github.com/pandas-profiling/pandas-profiling&gt;&lt;meta name=date content=&quot;2022-05-07 07:20:31.510237&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %%
# list of numerical variables
numerical_features = [feature for feature in df_num.columns if df_num[feature].dtypes != 'O']

print('Number of numerical variables: ', len(numerical_features))

# visualise the numerical variables
df_num[numerical_features].head()
# Out:
# Number of numerical variables:  9
#    Year  Kms_Driven  Fuel_Type  Seller_Type  Transmission  No_Of_Owners  \
# 0  2011      100000          0            1             0             1
# 1  2011      100000          0            0             0             1
# 2  2011       25000          0            1             0             1
# 3  2011       50000          0            0             0             2
# 4  2011      100000          0            1             0             1
#
#    Present_Price  Selling_Price  Insurance
# 0         750000         310000          1
# 1         750000         350000          1
# 2         850000         350000          1
# 3         900000         400000          1
# 4         750000         299000          0

# %%
#df_num.groupby('Present_Price')['Selling_Price'].median().plot()
#plt.xlabel('Present Price')
#plt.ylabel('Median Selling Price')
#plt.title("Seling Price vs Present Price")
#plt.show()
#plt.savefig("mygraph.png")

# %%
import tkinter
import matplotlib
import matplotlib.pyplot as plt
matplotlib.use('TkAgg')

# %%
#pip install PyQt5
df_num.head()
# Out:
#                   Car_Name Manufacturer  Year  Kms_Driven  Fuel_Type  \
# 0  Maruti Suzuki Dzire Ldi       Maruti  2011      100000          0
# 1  Maruti Suzuki Dzire Ldi       Maruti  2011      100000          0
# 2  Maruti Suzuki Dzire vdi       Maruti  2011       25000          0
# 3  Maruti Suzuki Dzire Zdi       Maruti  2011       50000          0
# 4  Maruti Suzuki Dzire Ldi       Maruti  2011      100000          0
#
#    Seller_Type  Transmission  No_Of_Owners  Present_Price  Selling_Price  \
# 0            1             0             1         750000         310000
# 1            0             0             1         750000         350000
# 2            1             0             1         850000         350000
# 3            0             0             2         900000         400000
# 4            1             0             1         750000         299000
#
#    Insurance
# 0          1
# 1          1
# 2          1
# 3          1
# 4          0

# %%
df_num['Current_Year'] = 2022

# %%
df_num['Car_Age'] = df_num['Current_Year'] - df_num['Year']

# %%
df_num.drop(['Current_Year'],axis=1,inplace=True)

# %%
df['Current_Year'] = 2022

# %%
df['Car_Age'] = df['Current_Year'] - df['Year']

# %%
df.drop(['Current_Year'],axis=1)
# Out:
#                       Car_Name Manufacturer  Year  Kms_Driven Fuel_Type  \
# 0      Maruti Suzuki Dzire Ldi       Maruti  2011      100000    Diesel
# 1      Maruti Suzuki Dzire Ldi       Maruti  2011      100000    Diesel
# 2      Maruti Suzuki Dzire vdi       Maruti  2011       25000    Diesel
# 3      Maruti Suzuki Dzire Zdi       Maruti  2011       50000    Diesel
# 4      Maruti Suzuki Dzire Ldi       Maruti  2011      100000    Diesel
# ...                        ...          ...   ...         ...       ...
# 1463   Toyota Fortuner 2.8 4X2       Toyota  2021        5698    Diesel
# 1464  Toyota Fortuner 2.8 4X4        Toyota  2021       20452    Diesel
# 1465   Toyota Fortuner 2.8 4X4       Toyota  2021        4800    Diesel
# 1466          Toyota Legender        Toyota  2021        9000    Diesel
# 1467       Toyota Legender 4X4       Toyota  2021       15478    Diesel
#
#      Seller_Type Transmission  No_Of_Owners  Present_Price  Selling_Price  \
# ...

# %%
# for feature in numerical_features:
# #     if feature!='YrSold':
# #         data=dataset.copy()
# #         ## We will capture the difference between year variable and year the house was sold for
# #         data[feature]=data['YrSold']-data[feature]

#         plt.scatter(df_num[feature],df_num['Selling_Price'])
#         plt.xlabel(feature)
#         plt.ylabel('Selling_Price')
#         plt.savefig('difference.png')

# %%
import seaborn as sns

# %%
for feature in numerical_features:
    sns.scatterplot(data=df_num,x=df[feature],y=df_num['Selling_Price'])

# %%
sns.pairplot(df_num)

# %%
df_num_wocm = df_num.copy()

# %%
df_num_wocm = df_num_wocm.drop(['Car_Name','Manufacturer'],axis=1)

# %%
df_num_wocm_X = df_num_wocm.drop(['Selling_Price'],axis=1)
df_num_wocm_y = df_num_wocm['Selling_Price']

# %%
# import statsmodels.api as sm
# from statsmodels.stats.outliers_influence import variance_inflation_factor
# vif = pd.DataFrame()
# vif["VIF Factor"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
# vif["features"] = X.columns

# %%
df_num_wocm
# Out:
#       Year  Kms_Driven  Fuel_Type  Seller_Type  Transmission  No_Of_Owners  \
# 0     2011      100000          0            1             0             1
# 1     2011      100000          0            0             0             1
# 2     2011       25000          0            1             0             1
# 3     2011       50000          0            0             0             2
# 4     2011      100000          0            1             0             1
# ...    ...         ...        ...          ...           ...           ...
# 1463  2021        5698          0            1             1             1
# 1464  2021       20452          0            1             0             1
# 1465  2021        4800          0            1             1             1
# 1466  2021        9000          0            1             0             1
# 1467  2021       15478          0            1             1             1
#
#       Present_Price  Selling_Price  Insurance  Car_Age
# ...

# %%
#Correlation
df_num.corr()
# Out:
#                    Year  Kms_Driven  Fuel_Type  Seller_Type  Transmission  \
# Year           1.000000   -0.505706   0.059459     0.065692      0.202439
# Kms_Driven    -0.505706    1.000000  -0.290720    -0.037912     -0.088399
# Fuel_Type      0.059459   -0.290720   1.000000     0.021744      0.076365
# Seller_Type    0.065692   -0.037912   0.021744     1.000000      0.012881
# Transmission   0.202439   -0.088399   0.076365     0.012881      1.000000
# No_Of_Owners  -0.155665    0.093409   0.060284    -0.036078     -0.065866
# Present_Price  0.277649    0.092379  -0.333933     0.074021      0.347451
# Selling_Price  0.472762   -0.091930  -0.246679     0.019201      0.292097
# Insurance      0.608839   -0.405198   0.070054     0.015917      0.193655
# Car_Age       -1.000000    0.505706  -0.059459    -0.065692     -0.202439
#
#                No_Of_Owners  Present_Price  Selling_Price  Insurance   Car_Age
# ...

# %%
import seaborn as sns
#get correlations of each features in dataset
corrmat = df_num.corr()
top_corr_features = corrmat.index
plt.figure(figsize=(20,20))
#plot heat map
g=sns.heatmap(df_num[top_corr_features].corr(),annot=True,cmap="RdYlGn")

# %%
df_num.head()
# Out:
#                   Car_Name Manufacturer  Year  Kms_Driven  Fuel_Type  \
# 0  Maruti Suzuki Dzire Ldi       Maruti  2011      100000          0
# 1  Maruti Suzuki Dzire Ldi       Maruti  2011      100000          0
# 2  Maruti Suzuki Dzire vdi       Maruti  2011       25000          0
# 3  Maruti Suzuki Dzire Zdi       Maruti  2011       50000          0
# 4  Maruti Suzuki Dzire Ldi       Maruti  2011      100000          0
#
#    Seller_Type  Transmission  No_Of_Owners  Present_Price  Selling_Price  \
# 0            1             0             1         750000         310000
# 1            0             0             1         750000         350000
# 2            1             0             1         850000         350000
# 3            0             0             2         900000         400000
# 4            1             0             1         750000         299000
#
#    Insurance  Car_Age
# 0          1       11
# 1          1       11
# 2          1       11
# ...

# %%
X = df_num[['Year','Kms_Driven','Fuel_Type','Seller_Type','Transmission','No_Of_Owners','Present_Price','Insurance','Car_Age']]
y = df_num['Selling_Price']

# %%
X1 = df_num[['Car_Name','Manufacturer','Year','Kms_Driven','Fuel_Type','Seller_Type','Transmission','No_Of_Owners','Present_Price','Insurance','Car_Age']]

# %%
X.shape
# Out:
# (1468, 9)

# %%
#variance Inflation Factor
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif = pd.DataFrame()
vif["VIF Factor"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif["features"] = X.columns
vif
# Out:
#    VIF Factor       features
# 0   39.554308           Year
# 1    1.581846     Kms_Driven
# 2    1.273106      Fuel_Type
# 3    1.012840    Seller_Type
# 4    1.207606   Transmission
# 5    1.039563   No_Of_Owners
# 6    1.525388  Present_Price
# 7    1.662549      Insurance
# 8    8.253492        Car_Age

# %%
#Feature Importance
from sklearn.ensemble import ExtraTreesRegressor
import matplotlib.pyplot as plt
model = ExtraTreesRegressor()
model.fit(X,y)
# Out:
# ExtraTreesRegressor()

# %%
print(model.feature_importances_)
# Out:
# [0.05394159 0.0753767  0.01419721 0.00282555 0.00833851 0.0021845
#  0.71340437 0.07150738 0.05822419]

# %%
#plot graph of feature importances for better visualization
feat_importances = pd.Series(model.feature_importances_, index=X.columns)
feat_importances.nlargest(9).plot(kind='barh')
plt.show()

# %%
df_num
# Out:
#                       Car_Name Manufacturer  Year  Kms_Driven  Fuel_Type  \
# 0      Maruti Suzuki Dzire Ldi       Maruti  2011      100000          0
# 1      Maruti Suzuki Dzire Ldi       Maruti  2011      100000          0
# 2      Maruti Suzuki Dzire vdi       Maruti  2011       25000          0
# 3      Maruti Suzuki Dzire Zdi       Maruti  2011       50000          0
# 4      Maruti Suzuki Dzire Ldi       Maruti  2011      100000          0
# ...                        ...          ...   ...         ...        ...
# 1463   Toyota Fortuner 2.8 4X2       Toyota  2021        5698          0
# 1464  Toyota Fortuner 2.8 4X4        Toyota  2021       20452          0
# 1465   Toyota Fortuner 2.8 4X4       Toyota  2021        4800          0
# 1466          Toyota Legender        Toyota  2021        9000          0
# 1467       Toyota Legender 4X4       Toyota  2021       15478          0
#
#       Seller_Type  Transmission  No_Of_Owners  Present_Price  Selling_Price  \
# ...

# %%
df
# Out:
#                       Car_Name Manufacturer  Year  Kms_Driven Fuel_Type  \
# 0      Maruti Suzuki Dzire Ldi       Maruti  2011      100000    Diesel
# 1      Maruti Suzuki Dzire Ldi       Maruti  2011      100000    Diesel
# 2      Maruti Suzuki Dzire vdi       Maruti  2011       25000    Diesel
# 3      Maruti Suzuki Dzire Zdi       Maruti  2011       50000    Diesel
# 4      Maruti Suzuki Dzire Ldi       Maruti  2011      100000    Diesel
# ...                        ...          ...   ...         ...       ...
# 1463   Toyota Fortuner 2.8 4X2       Toyota  2021        5698    Diesel
# 1464  Toyota Fortuner 2.8 4X4        Toyota  2021       20452    Diesel
# 1465   Toyota Fortuner 2.8 4X4       Toyota  2021        4800    Diesel
# 1466          Toyota Legender        Toyota  2021        9000    Diesel
# 1467       Toyota Legender 4X4       Toyota  2021       15478    Diesel
#
#      Seller_Type Transmission  No_Of_Owners  Present_Price  Selling_Price  \
# ...

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import make_column_transformer
from sklearn.pipeline import make_pipeline
from sklearn.metrics import r2_score

# %%
df_X=df.drop(['Selling_Price','Car_Age'],axis=1)
df_y=df['Selling_Price']

# %%
df_X=df.drop(['Selling_Price'],axis=1)
df_y=df['Selling_Price']

# %%
df_X.drop(['Car_Age'],axis=1,inplace=True)

# %%
df_X
# Out:
#                       Car_Name Manufacturer  Year  Kms_Driven Fuel_Type  \
# 0      Maruti Suzuki Dzire Ldi       Maruti  2011      100000    Diesel
# 1      Maruti Suzuki Dzire Ldi       Maruti  2011      100000    Diesel
# 2      Maruti Suzuki Dzire vdi       Maruti  2011       25000    Diesel
# 3      Maruti Suzuki Dzire Zdi       Maruti  2011       50000    Diesel
# 4      Maruti Suzuki Dzire Ldi       Maruti  2011      100000    Diesel
# ...                        ...          ...   ...         ...       ...
# 1463   Toyota Fortuner 2.8 4X2       Toyota  2021        5698    Diesel
# 1464  Toyota Fortuner 2.8 4X4        Toyota  2021       20452    Diesel
# 1465   Toyota Fortuner 2.8 4X4       Toyota  2021        4800    Diesel
# 1466          Toyota Legender        Toyota  2021        9000    Diesel
# 1467       Toyota Legender 4X4       Toyota  2021       15478    Diesel
#
#      Seller_Type Transmission  No_Of_Owners  Present_Price Insurance
# ...

# %%
from sklearn.model_selection import train_test_split
df_X_train,df_X_test,df_y_train,df_y_test=train_test_split(df_X,df_y,test_size=0.1)

# %%
df.drop(['Car_Age'],axis=1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1468 entries, 0 to 1467
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       1468 non-null   object
#  1   Manufacturer   1468 non-null   object
#  2   Year           1468 non-null   int64
#  3   Kms_Driven     1468 non-null   int64
#  4   Fuel_Type      1468 non-null   object
#  5   Seller_Type    1468 non-null   object
#  6   Transmission   1468 non-null   object
#  7   No_Of_Owners   1468 non-null   int64
#  8   Present_Price  1468 non-null   int32
#  9   Selling_Price  1468 non-null   int32
#  10  Insurance      1468 non-null   object
# dtypes: int32(2), int64(3), object(6)
# memory usage: 114.8+ KB

# %%
ohe=OneHotEncoder()
ohe.fit(df_X[['Car_Name','Manufacturer','Fuel_Type','Seller_Type','Transmission','Insurance']])
# Out:
# OneHotEncoder()

# %%
column_trans=make_column_transformer((OneHotEncoder(categories=ohe.categories_),['Car_Name','Manufacturer','Fuel_Type','Seller_Type','Transmission','Insurance']),
                                    remainder='passthrough')

# %%
from sklearn.linear_model import LinearRegression,Ridge,Lasso,ElasticNet
lr=LinearRegression()

# %%
pipe=make_pipeline(column_trans,lr)

# %%
pipe.fit(df_X_train,df_y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(categories=[array(['Honda Accord 2.4', 'Honda Accord Elegance',
#        'Honda Accord V6 Inspire', 'Honda Amaze iDtec S',
#        'Honda Amaze iDtec VX', 'Honda Amaze iDtech SCVT',
#        'Honda Amaze iDtech SX', 'Honda Amaze iDtech VCVT',
#        'Honda Amaze iDtech VX', 'Honda Amaze iVtec VX...
#        'Nissan', 'Renault', 'Toyota', 'Volkswagen'], dtype=object),
#                                                                             array(['CNG', 'Diesel', 'Electric', 'LPG', 'Petrol'], dtype=object),
#                                                                             array(['Dealer', 'Individual'], dtype=object),
# ...

# %%
y_pred=pipe.predict(df_X_test)

# %%
r2_score(df_y_test,y_pred)
# Out:
# 0.9263906897402608

# %%
# Finding the model with a random state of TrainTestSplit where the model was found to give almost 0.92 as r2_score
# scores=[]
# for i in range(1000):
#     X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.1,random_state=i)
#     lr=LinearRegression()
#     pipe=make_pipeline(column_trans,lr)
#     pipe.fit(X_train,y_train)
#     y_pred=pipe.predict(X_test)
#     scores.append(r2_score(y_test,y_pred))
    
#     np.argmax(scores)-655
#     scores[np.argmax(scores)]---0.924521555
    
# The best model is found at a certain random state
# X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.1,random_state=np.argmax(scores))
# lr=LinearRegression()
# pipe=make_pipeline(column_trans,lr)
# pipe.fit(X_train,y_train)
# y_pred=pipe.predict(X_test)
# r2_score(y_test,y_pred)

# %%
import pickle

# %%
pickle.dump(pipe,open('dfLinearRegressionModelNew.pkl','wb'))

# %%
df.tail()
# Out:
#                       Car_Name Manufacturer  Year  Kms_Driven Fuel_Type  \
# 1463   Toyota Fortuner 2.8 4X2       Toyota  2021        5698    Diesel
# 1464  Toyota Fortuner 2.8 4X4        Toyota  2021       20452    Diesel
# 1465   Toyota Fortuner 2.8 4X4       Toyota  2021        4800    Diesel
# 1466          Toyota Legender        Toyota  2021        9000    Diesel
# 1467       Toyota Legender 4X4       Toyota  2021       15478    Diesel
#
#      Seller_Type Transmission  No_Of_Owners  Present_Price  Selling_Price  \
# 1463  Individual    Automatic             1        4384000        3950000
# 1464  Individual       Manual             1        4522000        4300000
# 1465  Individual    Automatic             1        4792000        4500000
# 1466  Individual       Manual             1        4896000        4600000
# 1467  Individual    Automatic             1        5336000        5000000
#
#      Insurance
# 1463       Yes
# 1464       Yes
# 1465       Yes
# 1466       Yes
# ...

# %%
pipe.predict(pd.DataFrame(columns=['Car_Name','Manufacturer','Year','Kms_Driven','Fuel_Type','Seller_Type','Transmission','No_Of_Owners','Present_Price','Insurance'],
                          
                          data=np.array(['Toyota Fortuner 2.8 4X4','Toyota',2021,20452,'Diesel','Individual','Manual',1,4522000,'Yes']).reshape(1,10)))
# Out:
# array([3513340.45940088])

# %%
pipe.predict(pd.DataFrame(columns=['Car_Name','Manufacturer','Year','Kms_Driven','Fuel_Type','Seller_Type','Transmission','No_Of_Owners','Present_Price','Insurance'],
                          
                          data=np.array(['Maruti Suzuki Alto Lxi','Maruti',2015,80000,'Petrol','Individual','Automatic',1,380000,'No']).reshape(1,10)))
# Out:
# array([209383.34498405])

# %%
op=pipe.predict(pd.DataFrame(columns=['Car_Name','Manufacturer','Year','Kms_Driven','Fuel_Type','Seller_Type','Transmission','No_Of_Owners','Present_Price','Insurance'],
                          
                          data=np.array(['Toyota Legender 4X4','Toyota',20,15000,'Diesel','Individual','Automatic',1,5336000,'Yes']).reshape(1,10)))
op = abs(op)
print(op)
# Out:
# [72059693.94570927]

# %%
# evaluate an ridge regression model on the dataset
from numpy import mean
from numpy import std
from numpy import absolute
from pandas import read_csv
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedKFold
from sklearn.linear_model import Ridge


# define model evaluation method
cv = RepeatedKFold(n_splits=10, n_repeats=3, random_state=1)
# evaluate model
scores = cross_val_score(pipe, df_X, df_y, scoring='neg_mean_absolute_error', cv=cv, n_jobs=-1)
# force scores to be positive
scores = absolute(scores)
print('Mean MAE: %.3f (%.3f)' % (mean(scores), std(scores)))
# Out:
# Mean MAE: 127427.077 (19845.780)

# %%
# # evaluate an ridge regression model on the dataset
# from numpy import mean
# from numpy import std
# from numpy import absolute
# from pandas import read_csv
# from sklearn.model_selection import cross_val_score
# from sklearn.model_selection import RepeatedKFold
# from sklearn.linear_model import Ridge
# # load the dataset
# url = 'https://raw.githubusercontent.com/jbrownlee/Datasets/master/housing.csv'
# dataframe = read_csv(url, header=None)
# data = dataframe.values
# X, y = data[:, :-1], data[:, -1]
# # define model
# model = Ridge(alpha=1.0)
# # define model evaluation method
# cv = RepeatedKFold(n_splits=10, n_repeats=3, random_state=1)
# # evaluate model
# scores = cross_val_score(model, X, y, scoring='neg_mean_absolute_error', cv=cv, n_jobs=-1)
# # force scores to be positive
# scores = absolute(scores)
df.info()
# print('Mean MAE: %.3f (%.3f)' % (mean(scores), std(scores)))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1468 entries, 0 to 1467
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       1468 non-null   object
#  1   Manufacturer   1468 non-null   object
#  2   Year           1468 non-null   int64
#  3   Kms_Driven     1468 non-null   int64
#  4   Fuel_Type      1468 non-null   object
#  5   Seller_Type    1468 non-null   object
#  6   Transmission   1468 non-null   object
#  7   No_Of_Owners   1468 non-null   int64
#  8   Present_Price  1468 non-null   int32
#  9   Selling_Price  1468 non-null   int32
#  10  Insurance      1468 non-null   object
# dtypes: int32(2), int64(3), object(6)
# memory usage: 114.8+ KB

# %%
import statsmodels.formula.api as smf

# %%
# lm = smf.ols(formula='Selling_Price ~ Car_Name,Manufacturer,Year,Kms_Driven,Fuel_Type,Seller_Type,Transmission,No_Of_Owners,Present_Price,Insurance',data=df).fit()
# PatsyError: Error interpreting categorical data: all items must be hashable
#     Selling_Price ~ Car_Name,Manufacturer,Year,Kms_Driven,Fuel_Type,Seller_Type,Transmission,No_Of_Owners,Present_Price,Insurance
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^

# %%
pipe.score(df_X_test,df_y_test)
# Out:
# 0.9204072021977148

# %%
#Lasso Regression
ohe=OneHotEncoder()
ohe.fit(df_X[['Car_Name','Manufacturer','Fuel_Type','Seller_Type','Transmission','Insurance']])
# Out:
# OneHotEncoder()

# %%
column_trans=make_column_transformer((OneHotEncoder(categories=ohe.categories_),['Car_Name','Manufacturer','Fuel_Type','Seller_Type','Transmission','Insurance']),
                                    remainder='passthrough')

# %%
from sklearn.linear_model import LassoCV,RidgeCV,ElasticNetCV,Lasso,Ridge,ElasticNet

# %%
lassocv = LassoCV(cv=10,max_iter=2000,normalize=True,random_state=100)

# %%
lasso = Lasso(alpha=1.0,normalize=True,max_iter=2000,random_state=100)

# %%
Lasso_pipe=make_pipeline(column_trans,lasso)

# %%
Lasso_pipe.fit(df_X_train,df_y_train)
# Out:
# C:\Anaconda\lib\site-packages\sklearn\linear_model\_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Lasso())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#   warnings.warn(
# C:\Anaconda\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:609: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 151700704550.35938, tolerance: 62176919277.7535
# ...

# %%
y_predL=Lasso_pipe.predict(df_X_test)

# %%
r2_score(df_y_test,y_predL)
# Out:
# 0.9401357317796037

# %%
pickle.dump(Lasso_pipe,open('dfLassoRegressionModelNew.pkl','wb'))

# %%
#Ridge Regression
ohe=OneHotEncoder()
ohe.fit(df_X[['Car_Name','Manufacturer','Fuel_Type','Seller_Type','Transmission','Insurance']])
# Out:
# OneHotEncoder()

# %%
column_trans=make_column_transformer((OneHotEncoder(categories=ohe.categories_),['Car_Name','Manufacturer','Fuel_Type','Seller_Type','Transmission','Insurance']),
                                    remainder='passthrough')

# %%
ridge=Ridge(alpha=0.1,max_iter=2000,random_state=100,normalize=True)

# %%
Ridge_pipe=make_pipeline(column_trans,ridge)

# %%
Ridge_pipe.fit(df_X_train,df_y_train)
# Out:
# C:\Anaconda\lib\site-packages\sklearn\linear_model\_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
# ...

# %%
y_PredR=Ridge_pipe.predict(df_X_test)

# %%
r2_score(df_y_test,y_PredR)
# Out:
# 0.9268375968107381

# %%
pickle.dump(Ridge_pipe,open('dfRidgeRegressionModelNew.pkl','wb'))

# %%
#ElasticNet
ohe=OneHotEncoder()
ohe.fit(df_X[['Car_Name','Manufacturer','Fuel_Type','Seller_Type','Transmission','Insurance']])
# Out:
# OneHotEncoder()

# %%
column_trans=make_column_transformer((OneHotEncoder(categories=ohe.categories_),['Car_Name','Manufacturer','Fuel_Type','Seller_Type','Transmission','Insurance']),
                                    remainder='passthrough')

# %%
elastic = ElasticNet(alpha=0.0011,normalize=True,max_iter=2000,random_state=100)

# %%
elastic.l1_ratio
# Out:
# 0.5

# %%
elastic.alpha
# Out:
# 0.0011

# %%
Elastic_Pipe=make_pipeline(column_trans,elastic)

# %%
Elastic_Pipe.fit(df_X_train,df_y_train)
# Out:
# C:\Anaconda\lib\site-packages\sklearn\linear_model\_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), ElasticNet())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to original_alpha * np.sqrt(n_samples) if l1_ratio is 1, and to original_alpha * n_samples if l1_ratio is 0. For other values of l1_ratio, no analytic formula is available.
#   warnings.warn(
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
# ...

# %%
y_predE = Elastic_Pipe.predict(df_X_test)

# %%
r2_score(df_y_test,y_predE)
# Out:
# 0.854754606088786

# %%
pickle.dump(Elastic_Pipe,open('dfElasticNetRegressionNew.pkl','wb'))
